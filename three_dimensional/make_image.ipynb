# %%
#import matplotlib
import functions as func
import numpy as np
import os
import nrrd
import pydicom
#import pydicom.uid
#To write Dicom format

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2 as cv

# %%
filename = 'aortic.nrrd'

mask, header = nrrd.read(filename)
indices = ~np.all(mask[:,:,:] == 0 , axis=1).all(axis=0)

mask = mask[:, :, indices]

# %%
func.print3DImage(mask)
# Out:
# j: 1	Area: 0.7732382187635106
# j: 2	Area: 0.5711425125719617
# j: 3	Area: 0.3959769722620429
# j: 4	Area: 0.25062006507838985
# j: 5	Area: 0.13774546612965619
